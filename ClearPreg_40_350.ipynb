# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import pathlib
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.python.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# %%
## Google Colab related codes
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
DataDir = pathlib.Path('/content/drive/My Drive/Colab Notebooks/preg_imgs')
PositiveImages = list(DataDir.glob('processed_positive_images/*'))
NegativeImages = list(DataDir.glob('processed_negative_images/*'))

# %%
PIL.Image.open(str(PositiveImages[15]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=350x350>

# %%
PIL.Image.open(str(NegativeImages[15]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=350x350>

# %%
batch_size=32
train = tf.keras.preprocessing.image_dataset_from_directory(
    DataDir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(350, 350),
    label_mode='categorical',
    batch_size=batch_size
)
# Out:
# Found 9747 files belonging to 2 classes.
# Using 7798 files for training.

# %%
val = tf.keras.preprocessing.image_dataset_from_directory(
    DataDir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(350, 350),
    label_mode='categorical',
    batch_size=32
)
# Out:
# Found 9747 files belonging to 2 classes.
# Using 1949 files for validation.

# %%
ClassNames = train.class_names
print(ClassNames)
# Out:
# ['processed_negative_images', 'processed_positive_images']

# %%
## Training the model

ResNet = Sequential()

pretrained_ResNet = tf.keras.applications.ResNet50(include_top=False,
                                                   input_shape=(350,350,3),
                                                   pooling='max',
                                                   classes=2,
                                                   weights='imagenet')
for layer in pretrained_ResNet.layers:
  layer.trainable=False

ResNet.add(pretrained_ResNet)
ResNet.add(Flatten())
ResNet.add(Dense(256,activation='relu'))
ResNet.add(Dense(2, activation='softmax'))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step

# %%
ResNet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  module_wrapper (ModuleWrap  (None, 2048)              0
#  per)
#
#  module_wrapper_1 (ModuleWr  (None, 256)               524544
#  apper)
#
#  module_wrapper_2 (ModuleWr  (None, 2)                 514
#  apper)
#
# =================================================================
# Total params: 24112770 (91.98 MB)
# Trainable params: 525058 (2.00 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
ResNet.compile(optimizer=Adam(learning_rate=0.001),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
epochs=40
history = ResNet.fit(
    train,
    validation_data=val,
    epochs=epochs
)
# Out:
# Epoch 1/40
# 244/244 [==============================] - 812s 3s/step - loss: 1.5379 - accuracy: 0.6706 - val_loss: 0.6652 - val_accuracy: 0.6768
# Epoch 2/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.4643 - accuracy: 0.7816 - val_loss: 0.5075 - val_accuracy: 0.7599
# Epoch 3/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.4027 - accuracy: 0.8147 - val_loss: 0.4042 - val_accuracy: 0.8266
# Epoch 4/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.3787 - accuracy: 0.8296 - val_loss: 0.6175 - val_accuracy: 0.7158
# Epoch 5/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.3436 - accuracy: 0.8496 - val_loss: 0.4171 - val_accuracy: 0.8107
# Epoch 6/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.3257 - accuracy: 0.8565 - val_loss: 0.4569 - val_accuracy: 0.7978
# Epoch 7/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.3361 - accuracy: 0.8483 - val_loss: 0.3780 - val_accuracy: 0.8312
# Epoch 8/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.2838 - accuracy: 0.8755 - val_loss: 0.3751 - val_accuracy: 0.8353
# Epoch 9/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.2809 - accuracy: 0.8755 - val_loss: 0.3835 - val_accuracy: 0.8363
# Epoch 10/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.2663 - accuracy: 0.8913 - val_loss: 0.4159 - val_accuracy: 0.8363
# Epoch 11/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.2280 - accuracy: 0.9031 - val_loss: 0.3756 - val_accuracy: 0.8430
# Epoch 12/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.2140 - accuracy: 0.9090 - val_loss: 0.4688 - val_accuracy: 0.8230
# Epoch 13/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.1945 - accuracy: 0.9205 - val_loss: 0.3828 - val_accuracy: 0.8502
# Epoch 14/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.1769 - accuracy: 0.9249 - val_loss: 0.4019 - val_accuracy: 0.8527
# Epoch 15/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.1642 - accuracy: 0.9316 - val_loss: 0.4970 - val_accuracy: 0.8425
# Epoch 16/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.1477 - accuracy: 0.9415 - val_loss: 0.4944 - val_accuracy: 0.8240
# Epoch 17/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.1370 - accuracy: 0.9440 - val_loss: 0.4638 - val_accuracy: 0.8409
# Epoch 18/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.1106 - accuracy: 0.9565 - val_loss: 0.4185 - val_accuracy: 0.8553
# Epoch 19/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.1514 - accuracy: 0.9390 - val_loss: 0.5529 - val_accuracy: 0.8132
# Epoch 20/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.1062 - accuracy: 0.9596 - val_loss: 0.4425 - val_accuracy: 0.8635
# Epoch 21/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.0794 - accuracy: 0.9686 - val_loss: 0.4398 - val_accuracy: 0.8604
# Epoch 22/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.0741 - accuracy: 0.9738 - val_loss: 0.4345 - val_accuracy: 0.8574
# Epoch 23/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.1243 - accuracy: 0.9500 - val_loss: 0.4372 - val_accuracy: 0.8610
# Epoch 24/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.0670 - accuracy: 0.9732 - val_loss: 0.4811 - val_accuracy: 0.8697
# Epoch 25/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.0886 - accuracy: 0.9635 - val_loss: 0.6504 - val_accuracy: 0.8209
# Epoch 26/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.0671 - accuracy: 0.9735 - val_loss: 0.5116 - val_accuracy: 0.8656
# Epoch 27/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.0414 - accuracy: 0.9856 - val_loss: 0.5927 - val_accuracy: 0.8568
# Epoch 28/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.0663 - accuracy: 0.9751 - val_loss: 0.5400 - val_accuracy: 0.8599
# Epoch 29/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.0555 - accuracy: 0.9777 - val_loss: 0.5251 - val_accuracy: 0.8784
# Epoch 30/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.0447 - accuracy: 0.9835 - val_loss: 1.2597 - val_accuracy: 0.7640
# Epoch 31/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.1916 - accuracy: 0.9219 - val_loss: 0.4792 - val_accuracy: 0.8579
# Epoch 32/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.0518 - accuracy: 0.9817 - val_loss: 0.5507 - val_accuracy: 0.8656
# Epoch 33/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.0203 - accuracy: 0.9947 - val_loss: 0.5143 - val_accuracy: 0.8815
# Epoch 34/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.0401 - accuracy: 0.9860 - val_loss: 0.6058 - val_accuracy: 0.8748
# Epoch 35/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.0917 - accuracy: 0.9664 - val_loss: 0.5814 - val_accuracy: 0.8707
# Epoch 36/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.0291 - accuracy: 0.9895 - val_loss: 0.5195 - val_accuracy: 0.8733
# Epoch 37/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.0139 - accuracy: 0.9971 - val_loss: 0.5755 - val_accuracy: 0.8769
# Epoch 38/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.0104 - accuracy: 0.9978 - val_loss: 0.5776 - val_accuracy: 0.8784
# Epoch 39/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.0063 - accuracy: 0.9995 - val_loss: 0.6090 - val_accuracy: 0.8707
# Epoch 40/40
# 244/244 [==============================] - 17s 68ms/step - loss: 0.0256 - accuracy: 0.9919 - val_loss: 0.6536 - val_accuracy: 0.8722

# %%
fig = plt.gcf()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.axis(ymin=0.3,ymax=1)
plt.grid()
plt.title('Model Performance')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train','validation'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.grid()
plt.title('Model Performance')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train','validation'])
plt.show()

# %%
ResNet.save('ClearPreg_weights')

# %%
ResNet.save('/content/drive/My Drive/Colab Notebooks/ClearPreg_weights_40_350')
